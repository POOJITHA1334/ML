# %% [markdown]
# <a href="https://colab.research.google.com/github/POOJITHA1334/ML/blob/main/datasets-practice/air_quality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/c4_epa_air_quality.csv')
df
# Out:
#      Unnamed: 0  date_local            state_name           county_name  \
# 0             0  2018-01-01               Arizona              Maricopa
# 1             1  2018-01-01                  Ohio               Belmont
# 2             2  2018-01-01               Wyoming                 Teton
# 3             3  2018-01-01          Pennsylvania          Philadelphia
# 4             4  2018-01-01                  Iowa                  Polk
# ..          ...         ...                   ...                   ...
# 255         255  2018-01-01  District Of Columbia  District of Columbia
# 256         256  2018-01-01             Wisconsin                 Dodge
# 257         257  2018-01-01              Kentucky             Jefferson
# 258         258  2018-01-01              Nebraska               Douglas
# 259         259  2018-01-01        North Carolina                  Wake
#
#          city_name                                    local_site_name  \
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0  arithmetic_mean         aqi
# count  260.000000       260.000000  260.000000
# mean   129.500000         0.403169    6.757692
# std     75.199734         0.317902    7.061707
# min      0.000000         0.000000    0.000000
# 25%     64.750000         0.200000    2.000000
# 50%    129.500000         0.276315    5.000000
# 75%    194.250000         0.516009    9.000000
# max    259.000000         1.921053   50.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        260 non-null    int64
#  1   date_local        260 non-null    object
#  2   state_name        260 non-null    object
#  3   county_name       260 non-null    object
#  4   city_name         260 non-null    object
#  5   local_site_name   257 non-null    object
#  6   parameter_name    260 non-null    object
#  7   units_of_measure  260 non-null    object
#  8   arithmetic_mean   260 non-null    float64
#  9   aqi               260 non-null    int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 20.4+ KB

# %%
df.tail()
# Out:
#      Unnamed: 0  date_local            state_name           county_name  \
# 255         255  2018-01-01  District Of Columbia  District of Columbia
# 256         256  2018-01-01             Wisconsin                 Dodge
# 257         257  2018-01-01              Kentucky             Jefferson
# 258         258  2018-01-01              Nebraska               Douglas
# 259         259  2018-01-01        North Carolina                  Wake
#
#          city_name        local_site_name   parameter_name   units_of_measure  \
# 255     Washington              Near Road  Carbon monoxide  Parts per million
# 256       Kekoskee  HORICON WILDLIFE AREA  Carbon monoxide  Parts per million
# 257     Louisville           CANNONS LANE  Carbon monoxide  Parts per million
# 258          Omaha                    NaN  Carbon monoxide  Parts per million
# 259  Not in a city             Triple Oak  Carbon monoxide  Parts per million
#
#      arithmetic_mean  aqi
# 255         0.244444    3
# ...

# %%
df.isnull()
# Out:
#      Unnamed: 0  date_local  state_name  county_name  city_name  \
# 0         False       False       False        False      False
# 1         False       False       False        False      False
# 2         False       False       False        False      False
# 3         False       False       False        False      False
# 4         False       False       False        False      False
# ..          ...         ...         ...          ...        ...
# 255       False       False       False        False      False
# 256       False       False       False        False      False
# 257       False       False       False        False      False
# 258       False       False       False        False      False
# 259       False       False       False        False      False
#
#      local_site_name  parameter_name  units_of_measure  arithmetic_mean    aqi
# 0              False           False             False            False  False
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# date_local          0
# state_name          0
# county_name         0
# city_name           0
# local_site_name     3
# parameter_name      0
# units_of_measure    0
# arithmetic_mean     0
# aqi                 0
# dtype: int64

# %%
df["local_site_name"].replace(np.nan,'Near Road',inplace=True)
df
# Out:
#      Unnamed: 0  date_local            state_name           county_name  \
# 0             0  2018-01-01               Arizona              Maricopa
# 1             1  2018-01-01                  Ohio               Belmont
# 2             2  2018-01-01               Wyoming                 Teton
# 3             3  2018-01-01          Pennsylvania          Philadelphia
# 4             4  2018-01-01                  Iowa                  Polk
# ..          ...         ...                   ...                   ...
# 255         255  2018-01-01  District Of Columbia  District of Columbia
# 256         256  2018-01-01             Wisconsin                 Dodge
# 257         257  2018-01-01              Kentucky             Jefferson
# 258         258  2018-01-01              Nebraska               Douglas
# 259         259  2018-01-01        North Carolina                  Wake
#
#          city_name                                    local_site_name  \
# ...

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'date_local',
#  'state_name',
#  'county_name',
#  'city_name',
#  'local_site_name',
#  'parameter_name',
#  'units_of_measure',
#  'arithmetic_mean',
#  'aqi']

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# date_local          0
# state_name          0
# county_name         0
# city_name           0
# local_site_name     0
# parameter_name      0
# units_of_measure    0
# arithmetic_mean     0
# aqi                 0
# dtype: int64

# %%
df_air = df[df.aqi < 3]

# %%
df_air.state_name.value_counts()
# Out:
# New York                5
# Minnesota               5
# Texas                   5
# Pennsylvania            4
# North Carolina          4
# Wyoming                 3
# Ohio                    3
# Maryland                3
# Oklahoma                3
# Kentucky                3
# Illinois                2
# Florida                 2
# California              2
# Missouri                2
# Iowa                    2
# New Hampshire           2
# New Jersey              1
# Indiana                 1
# South Carolina          1
# Michigan                1
# District Of Columbia    1
# Maine                   1
# Arizona                 1
# Oregon                  1
# Mississippi             1
# Connecticut             1
# Louisiana               1
# Massachusetts           1
# Rhode Island            1
# Montana                 1
# Hawaii                  1
# North Dakota            1
# Alabama                 1
# Georgia                 1
# Tennessee               1
# ...

# %%
df_gases = df[df.aqi > 3]

# %%
df_gases.county_name.value_counts()
# Out:
# Los Angeles       14
# Maricopa           8
# Wayne              8
# San Bernardino     6
# Alameda            4
#                   ..
# Imperial           1
# Allegheny          1
# Richmond City      1
# Hartford           1
# King               1
# Name: county_name, Length: 69, dtype: int64

# %%
df[df.local_site_name=='Near Road']
# Out:
#      Unnamed: 0  date_local            state_name           county_name  \
# 7             7  2018-01-01          Pennsylvania                  Erie
# 55           55  2018-01-01         West Virginia               Kanawha
# 93           93  2018-01-01              Oklahoma              Oklahoma
# 255         255  2018-01-01  District Of Columbia  District of Columbia
# 258         258  2018-01-01              Nebraska               Douglas
#
#          city_name local_site_name   parameter_name   units_of_measure  \
# 7             Erie       Near Road  Carbon monoxide  Parts per million
# 55      Charleston       Near Road  Carbon monoxide  Parts per million
# 93   Oklahoma City       Near Road  Carbon monoxide  Parts per million
# 255     Washington       Near Road  Carbon monoxide  Parts per million
# 258          Omaha       Near Road  Carbon monoxide  Parts per million
#
#      arithmetic_mean  aqi
# 7           0.200000    2
# 55          0.226316    3
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0            int64
# date_local           object
# state_name           object
# county_name          object
# city_name            object
# local_site_name      object
# parameter_name       object
# units_of_measure     object
# arithmetic_mean     float64
# aqi                   int64
# dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df['arithmetic_mean'].hist()
# Out:
# <Axes: >

# %%
plt.bar(df["arithmetic_mean"],df["aqi"])
plt.xlabel("air quality index")
plt.ylabel('arithmetic_mean')
plt.title("mean of gases")
plt.show()

# %%
Q1=df['arithmetic_mean'].quantile(0.25)
Q3=df['arithmetic_mean'].quantile(0.75)
IQR = Q3-Q1
lower=Q1-1.5*IQR
upper=Q3+1.5*IQR
upper_arrays=np.where(df['arithmetic_mean']>=upper)[0]
lower_arrays=np.where(df['arithmetic_mean']<=lower)[0]
Q1
# Out:
# 0.2

# %%
import seaborn as sns
df.corr()
sns.heatmap(df.corr())
# Out:
# <ipython-input-21-30a6d455a720>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
# <ipython-input-21-30a6d455a720>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
air_index=df['aqi']
air_index
# Out:
# 0      7
# 1      5
# 2      2
# 3      3
# 4      3
#       ..
# 255    3
# 256    2
# 257    2
# 258    9
# 259    2
# Name: aqi, Length: 260, dtype: int64

# %%
air_index.max()
# Out:
# 50

# %%
air_index=air_index.max()-df['aqi']
air_index
# Out:
# 0      43
# 1      45
# 2      48
# 3      47
# 4      47
#        ..
# 255    47
# 256    48
# 257    48
# 258    41
# 259    48
# Name: aqi, Length: 260, dtype: int64

# %%
sns.boxplot(air_index)
# Out:
# <Axes: >

# %%
df_bar = pd.DataFrame(np.random.randint(low=2, high=100, size=(10,2)),columns=['aqi', 'arithmetic mean'])
df_bar
# Out:
#    aqi  arithmetic mean
# 0   94               94
# 1    7               68
# 2   11               41
# 3   78               79
# 4   49               48
# 5   66               89
# 6   39               22
# 7   75               50
# 8   54               26
# 9   14               24

# %%
df_bar.plot.bar()
# Out:
# <Axes: >

# %%
df_bar = pd.DataFrame(np.random.randint(low=2, high=100, size=(10,2)),columns=['aqi', 'unnamed'])
df_bar
# Out:
#    aqi  unnamed
# 0   17       19
# 1   72       78
# 2   88       78
# 3   79       46
# 4   74       33
# 5   17       84
# 6   60       48
# 7   14       41
# 8   25       79
# 9   49       51

# %%
df_bar.plot.bar()
# Out:
# <Axes: >

# %%
labels = 'aqi', 'arithmetic_mean', 'unnamed'
sections = [56, 66, 24]
colors = ['g', 'c', 'y']
plt.pie(sections, labels=labels, colors=colors, autopct='%.2f%%', explode = (0, 0.1, 0))
# Out:
# ([<matplotlib.patches.Wedge at 0x7c9917c487f0>,
# ...
#  [Text(0.39346807193873345, 1.0272209481726977, 'aqi'),
#   Text(-0.9265879053108963, -0.7625187563146009, 'arithmetic_mean'),
#   Text(0.9565483303711487, -0.543153101495488, 'unnamed')],
#  [Text(0.21461894833021822, 0.560302335366926, '38.36%'),
#   Text(-0.5405096114313561, -0.4448026078501838, '45.21%'),
#   Text(0.5217536347478993, -0.29626532808844797, '16.44%')])

# %%
df.local_site_name.nunique()
# Out:
# 253

# %%
a=df.head(10)

# %%
x=a.iloc[:,8].values
x
# Out:
# array([0.473684, 0.263158, 0.111111, 0.3     , 0.215789, 0.994737,
#        0.2     , 0.2     , 0.4     , 0.3     ])

# %%
x=x.reshape(-1, 1)
x
# Out:
# array([[0.473684],
#        [0.263158],
#        [0.111111],
#        [0.3     ],
#        [0.215789],
#        [0.994737],
#        [0.2     ],
#        [0.2     ],
#        [0.4     ],
#        [0.3     ]])

# %%
y=a.iloc[:,9].values
y
# Out:
# array([ 7,  5,  2,  3,  3, 14,  2,  2,  5,  6])

# %%
from sklearn.linear_model import LinearRegression
harmness=LinearRegression()
harmness.fit(x,y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y,color='red')
plt.plot(x,harmness.predict(x),color='blue')
plt.title('LinearRegression')
plt.xlabel('arithmetic_mean')
plt.ylabel('aqi')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        260 non-null    int64
#  1   date_local        260 non-null    object
#  2   state_name        260 non-null    object
#  3   county_name       260 non-null    object
#  4   city_name         260 non-null    object
#  5   local_site_name   260 non-null    object
#  6   parameter_name    260 non-null    object
#  7   units_of_measure  260 non-null    object
#  8   arithmetic_mean   260 non-null    float64
#  9   aqi               260 non-null    int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 20.4+ KB

# %%
plt.subplots(figsize=(12,6))
sns.heatmap(df.corr(),annot=True,cmap='Blues',)
# Out:
# <ipython-input-39-77b6117d440d>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap='Blues',)
# <Axes: >

# %%
from sklearn.preprocessing import PolynomialFeatures
air_quality=PolynomialFeatures(degree=2,include_bias=False)

# %%
a_index=air_quality.fit_transform(x)
a_index.shape
# Out:
# (10, 2)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(a_index,y,test_size=0.3,random_state=101)

# %%
y=df['arithmetic_mean']
y
# Out:
# 0      0.473684
# 1      0.263158
# 2      0.111111
# 3      0.300000
# 4      0.215789
#          ...
# 255    0.244444
# 256    0.200000
# 257    0.163158
# 258    0.421053
# 259    0.188889
# Name: arithmetic_mean, Length: 260, dtype: float64

# %%
b=LinearRegression()

# %%
b.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=b.predict(x_test)

# %%
pd.DataFrame({'Y_test': y_test,'Y_Pred': y_pred,'Residuals':(y_test-y_pred)})
# Out:
#    Y_test    Y_Pred  Residuals
# 0       5  7.131826  -2.131826
# 1       2 -0.268003   2.268003
# 2       7  8.593676  -1.593676

# %%
from sklearn import metrics
a_checking=metrics.mean_absolute_error(y_test,y_pred)
a_checking=metrics.mean_squared_error(y_test,y_pred)
a_checking_rmean=np.sqrt(a_checking)
a_checking_rmean
# Out:
# 2.018937293142127

# %%
x_b=np.c_[np.ones([x.shape[0],1]),x]
x_b
# Out:
# array([[1.      , 0.473684],
#        [1.      , 0.263158],
#        [1.      , 0.111111],
#        [1.      , 0.3     ],
#        [1.      , 0.215789],
#        [1.      , 0.994737],
#        [1.      , 0.2     ],
#        [1.      , 0.2     ],
#        [1.      , 0.4     ],
#        [1.      , 0.3     ]])

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def sigmoid(z):
  return 1/(1+np.exp(-z))

# %%
y=np.column_stack((np.ones(y.shape[0]),y))

# %%
run_features=y.shape[1]
params=np.zeros(run_features)

# %%
learning_rate=0.1
run_iterations=10000
