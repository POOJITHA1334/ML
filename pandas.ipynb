# %% [markdown]
# <a href="https://colab.research.google.com/github/POOJITHA1334/ML/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **pandas**
#
# 1. preprocessing large set of data
# 2. pandas are stored in dataframes(data structures)
# 3. functions and operations are accurately done in pandas.
# 4. pandas run in numpy.
# 5. scipy(all math functions)
# 6. manipulating numerical data and time series.
# 7. software library written for python programming

# %% [markdown]
# **roboflow**
# data collection->organise->labelling->process->train->deploy

# %% [markdown]
# **series and** **dataframes**
# 1. series-> 1D data
# 2. dataframes->3D(rows and columns)

# %% [markdown]
# **difference between numpy and pandas**
# 1. numpy accessed only with index
# 2. pandas accessed with rows,columns,index. we can store data in different orders.

# %%
import pandas as pd
import numpy as np

# %%
import numpy as np
a=np.array([10,3,4,6,8])
a
# Out:
# array([10,  3,  4,  6,  8])

# %%
a=np.array([10,3,4,6,8])
type(a)
# Out:
# numpy.ndarray

# %%
a[3]
# Out:
# 6

# %%
import pandas as pd
s=pd.Series([2,4,5,6,80])
print(s)
type(s)
# Out:
# 0     2
# 1     4
# 2     5
# 3     6
# 4    80
# dtype: int64
# pandas.core.series.Series

# %%
import pandas as pd
s=pd.Series([2,4,5,6,80])
print(s)
type(s)
s[3]
# Out:
# 0     2
# 1     4
# 2     5
# 3     6
# 4    80
# dtype: int64
# 6

# %%
s.drop(3)
# Out:
# 0     2
# 1     4
# 2     5
# 4    80
# dtype: int64

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
a=pd.Series([10,12,13,4,5],index=['p','o','o','j','i'])
print(a)
# Out:
# p    10
# o    12
# o    13
# j     4
# i     5
# dtype: int64

# %%
a.loc['o']
# Out:
# o    12
# o    13
# dtype: int64

# %%
a.iloc[2]
# Out:
# 13

# %%
data=[['pooji',19,'13/04/2004'],['yuva',None,None],['sri',None,'12/05/2003']]
print(data)
# Out:
# [['pooji', 19, '13/04/2004'], ['yuva', None, None], ['sri', None, '12/05/2003']]

# %%
df=pd.DataFrame(data)
df
# Out:
#        0     1           2
# 0  pooji  19.0  13/04/2004
# 1   yuva   NaN        None
# 2    sri   NaN  12/05/2003

# %%
df[0:1]
# Out:
#        0     1           2
# 0  pooji  19.0  13/04/2004

# %%
df[0:2]
# Out:
#        0     1           2
# 0  pooji  19.0  13/04/2004
# 1   yuva   NaN        None

# %%
df[0][0]
# Out:
# 'pooji'

# %%
df[[0,2]]
# Out:
#        0           2
# 0  pooji  13/04/2004
# 1   yuva        None
# 2    sri  12/05/2003

# %%
df[[0,1]]
# Out:
#        0     1
# 0  pooji  19.0
# 1   yuva   NaN
# 2    sri   NaN

# %%
df[0]
# Out:
# 0    pooji
# 1     yuva
# 2      sri
# Name: 0, dtype: object

# %%
df[0][1]
# Out:
# 'yuva'

# %%
df[1:2]
# Out:
#       0   1     2
# 1  yuva NaN  None

# %%
df=pd.DataFrame(data,columns=['Firstname','Age','DOB'])
df
# Out:
#   Firstname   Age         DOB
# 0     pooji  19.0  13/04/2004
# 1      yuva   NaN        None
# 2       sri   NaN  12/05/2003

# %%
df['Firstname']
df['Age']
# Out:
# 0    19.0
# 1     NaN
# 2     NaN
# Name: Age, dtype: float64

# %%
df['Firstname'][0]
# Out:
# 'pooji'

# %%
df.loc[0,'Firstname']
# Out:
# 'pooji'

# %%
df.iloc[0,0]
# Out:
# 'pooji'

# %%
df.iloc[0:1]
# Out:
#   Firstname   Age         DOB
# 0     pooji  19.0  13/04/2004

# %%
c=pd.Series([3,4,6])
c
# Out:
# 0    3
# 1    4
# 2    6
# dtype: int64

# %%
c.plot()
# Out:
# <Axes: >

# %%
c.hist(bins=2)
# Out:
# <Axes: >

# %%
c.plot.bar()
# Out:
# <Axes: >

# %%
c=c.to_numpy()
type(c)
# Out:
# numpy.ndarray

# %%
df
# Out:
#   Firstname   Age         DOB
# 0     pooji  19.0  13/04/2004
# 1      yuva   NaN        None
# 2       sri   NaN  12/05/2003

# %%
df.isnull().sum()
# Out:
# Firstname    0
# Age          2
# DOB          1
# dtype: int64

# %%
da=[['pooji',19,'13/04/2004','eee'],['yuva',None,None,'eee'],['sri',None,'12/05/2003','ece'],[None,None,None,'ece'],['leka',None,None,None],['ram',None,None,None],['sita',None,'12/05/2003','ece']]
df=pd.DataFrame(da,columns=['Firstname','Age','DOB','dept'])
df
# Out:
#   Firstname   Age         DOB  dept
# 0     pooji  19.0  13/04/2004   eee
# 1      yuva   NaN        None   eee
# 2       sri   NaN  12/05/2003   ece
# 3      None   NaN        None   ece
# 4      leka   NaN        None  None
# 5       ram   NaN        None  None
# 6      sita   NaN  12/05/2003   ece

# %%
df.isnull().sum()
# Out:
# Firstname    1
# Age          6
# DOB          4
# dept         2
# dtype: int64

# %%
df.dropna()
# Out:
#   Firstname   Age         DOB dept
# 0     pooji  19.0  13/04/2004  eee

# %%
df.drop(['Age'],axis=1,inplace=True)
df
# Out:
#   Firstname         DOB  dept
# 0     pooji  13/04/2004   eee
# 1      yuva        None   eee
# 2       sri  12/05/2003   ece
# 3      None        None   ece
# 4      leka        None  None
# 5       ram        None  None
# 6      sita  12/05/2003   ece

# %%
df.drop([0,6,3,4]) #deleting the particular row
# Out:
#   Firstname         DOB  dept
# 1      yuva        None   eee
# 2       sri  12/05/2003   ece
# 5       ram        None  None

# %%
c
# Out:
# array([3, 4, 6])

# %%
c>3
# Out:
# array([False,  True,  True])

# %%
c[c>3]
# Out:
# array([4, 6])

# %%
c[c%2!=0]
# Out:
# array([3])

# %%
import numpy as np
a=np.array([89,90,896,456,455,390,287])
a[a%2==0]
# Out:
# array([ 90, 896, 456, 390])

# %%
da
# Out:
# [['pooji', 19, '13/04/2004', 'eee'],
#  ['yuva', None, None, 'eee'],
#  ['sri', None, '12/05/2003', 'ece'],
#  [None, None, None, 'ece'],
#  ['leka', None, None, None],
#  ['ram', None, None, None],
#  ['sita', None, '12/05/2003', 'ece']]

# %%
da=[['pooji',19,'13/04/2004','eee'],['yuva',None,None,'eee'],['sri',None,'12/05/2003','ece'],[None,None,None,'ece'],['leka',None,None,None],['ram',None,None,None],['sita',None,'12/05/2003','ece']]
df=pd.DataFrame(da,columns=['Firstname','Age','DOB','dept'])
df
# Out:
#   Firstname   Age         DOB  dept
# 0     pooji  19.0  13/04/2004   eee
# 1      yuva   NaN        None   eee
# 2       sri   NaN  12/05/2003   ece
# 3      None   NaN        None   ece
# 4      leka   NaN        None  None
# 5       ram   NaN        None  None
# 6      sita   NaN  12/05/2003   ece

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Firstname  6 non-null      object
#  1   Age        1 non-null      float64
#  2   DOB        3 non-null      object
#  3   dept       5 non-null      object
# dtypes: float64(1), object(3)
# memory usage: 352.0+ bytes

# %%
df.drop(['Age'],axis=1,inplace=True)
df
# Out:
#   Firstname         DOB  dept
# 0     pooji  13/04/2004   eee
# 1      yuva        None   eee
# 2       sri  12/05/2003   ece
# 3      None        None   ece
# 4      leka        None  None
# 5       ram        None  None
# 6      sita  12/05/2003   ece

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Firstname  6 non-null      object
#  1   DOB        3 non-null      object
#  2   dept       5 non-null      object
# dtypes: object(3)
# memory usage: 296.0+ bytes

# %%
df['Firstname'].str.contains('e')
# Out:
# 0    False
# 1    False
# 2    False
# 3     None
# 4     True
# 5    False
# 6    False
# Name: Firstname, dtype: object

# %%
df['Firstname'].str.contains('a')
# Out:
# 0    False
# 1     True
# 2    False
# 3     None
# 4     True
# 5     True
# 6     True
# Name: Firstname, dtype: object

# %%
print(df.shape)
print(df.size)
print(df.axes)
print(df.ndim)
print(df.dtypes)
print(df.drop)
print(df.columns)
print(df.values)
# Out:
# (7, 3)
# 21
# [RangeIndex(start=0, stop=7, step=1), Index(['Firstname', 'DOB', 'dept'], dtype='object')]
# 2
# Firstname    object
# DOB          object
# dept         object
# dtype: object
# <bound method DataFrame.drop of   Firstname         DOB  dept
# 0     pooji  13/04/2004   eee
# 1      yuva        None   eee
# 2       sri  12/05/2003   ece
# 3      None        None   ece
# 4      leka        None  None
# 5       ram        None  None
# 6      sita  12/05/2003   ece>
# Index(['Firstname', 'DOB', 'dept'], dtype='object')
# [['pooji' '13/04/2004' 'eee']
#  ['yuva' None 'eee']
#  ['sri' '12/05/2003' 'ece']
#  [None None 'ece']
#  ['leka' None None]
#  ['ram' None None]
#  ['sita' '12/05/2003' 'ece']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Firstname  6 non-null      object
#  1   DOB        3 non-null      object
#  2   dept       5 non-null      object
# dtypes: object(3)
# memory usage: 296.0+ bytes

# %%
df.tail()
# Out:
#   Firstname         DOB  dept
# 2       sri  12/05/2003   ece
# 3      None        None   ece
# 4      leka        None  None
# 5       ram        None  None
# 6      sita  12/05/2003   ece

# %%
k=pd.concat([df,df])
k
# Out:
#   Firstname         DOB  dept
# 0     pooji  13/04/2004   eee
# 1      yuva        None   eee
# 2       sri  12/05/2003   ece
# 3      None        None   ece
# 4      leka        None  None
# 5       ram        None  None
# 6      sita  12/05/2003   ece
# 0     pooji  13/04/2004   eee
# 1      yuva        None   eee
# 2       sri  12/05/2003   ece
# 3      None        None   ece
# 4      leka        None  None
# 5       ram        None  None
# 6      sita  12/05/2003   ece

# %%
df.describe()
# Out:
#        Firstname         DOB dept
# count          6           3    5
# unique         6           2    2
# top        pooji  12/05/2003  ece
# freq           1           2    3

# %%
df.DOB
# Out:
# 0    13/04/2004
# 1          None
# 2    12/05/2003
# 3          None
# 4          None
# 5          None
# 6    12/05/2003
# Name: DOB, dtype: object

# %%
df[['Firstname','DOB']]
# Out:
#   Firstname         DOB
# 0     pooji  13/04/2004
# 1      yuva        None
# 2       sri  12/05/2003
# 3      None        None
# 4      leka        None
# 5       ram        None
# 6      sita  12/05/2003

# %%
df.loc[0][0]
# Out:
# 'pooji'

# %%
df.loc[1,'Firstname']
# Out:
# 'yuva'

# %%
df.iloc[0][1]
# Out:
# '13/04/2004'

# %%
df["DOB"][1]='20/09/2002'
df
# Out:
#   Firstname         DOB  dept
# 0     pooji  13/04/2004   eee
# 1      yuva  20/09/2002   eee
# 2       sri  12/05/2003   ece
# 3      None        None   ece
# 4      leka        None  None
# 5       ram        None  None
# 6      sita  12/05/2003   ece

# %% [markdown]
# **reading from file**
# 1. csv
# 2. JSON
# 3. HTML
# 4. EXCEL
# 5. SQL Queries
# 6. TSV

# %%
import pandas as pd
df=pd.read_html("https://en.wikipedia.org/wiki/List_of_highest-grossing_films")
df
# Out:
# [    Rank  Peak                                          Title  \
#  0      1     1                                         Avatar
#  1      2     1                              Avengers: Endgame
#  2      3     3                       Avatar: The Way of Water
#  3      4     1                                        Titanic
#  4      5     3                   Star Wars: The Force Awakens
#  5      6     4                         Avengers: Infinity War
#  6      7     6                        Spider-Man: No Way Home
#  7      8     3                                 Jurassic World
#  8      9     7                                  The Lion King
#  9     10     3                                   The Avengers
#  10    11     4                                      Furious 7
#  11    12    11                              Top Gun: Maverick
#  12    13    10                                      Frozen II
#  13    14    14                                       Barbie †
# ...

# %%
import pandas as pd
df=pd.read_table("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/chipotle.tsv")
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
df.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
type(df.item_price[0])
# Out:
# str

# %%
df.item_price=df.item_price.str.replace('$','')
df.head(10)
# Out:
# <ipython-input-87-5f86cc00013c>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.item_price=df.item_price.str.replace('$','')
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
# ...

# %%
df.item_price=df.item_price.astype(float)
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
type(df.item_price[0])
# Out:
# numpy.float64

# %%
#df.item_price=df.item_price*100
#df

# %%
df_drink=df[df.item_price<1.1]
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
df.item_name.unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
# ...

# %%
df_drink.item_name.unique()
# Out:
# array(['Canned Soda', 'Bottled Water'], dtype=object)

# %%
df_drink.item_name.nunique()
# Out:
# 2

# %%
df_drink.item_name.value_counts()
# Out:
# Canned Soda      84
# Bottled Water    22
# Name: item_name, dtype: int64

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
df[df.item_name=='Chicken Bowl']
# Out:
#       order_id  quantity     item_name  \
# 4            2         2  Chicken Bowl
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# ...        ...       ...           ...
# 4590      1825         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# ...                                                 ...         ...
# ...

# %%
df[df.item_name=='Steak Salad Bowl']
# Out:
#       order_id  quantity         item_name  \
# 281        123         2  Steak Salad Bowl
# 606        250         1  Steak Salad Bowl
# 607        250         1  Steak Salad Bowl
# 613        253         2  Steak Salad Bowl
# 749        309         1  Steak Salad Bowl
# 1159       478         1  Steak Salad Bowl
# 1311       534         1  Steak Salad Bowl
# 1505       612         1  Steak Salad Bowl
# 1571       637         1  Steak Salad Bowl
# 1590       644         1  Steak Salad Bowl
# 1816       734         1  Steak Salad Bowl
# 2401       953         1  Steak Salad Bowl
# 2439       969         1  Steak Salad Bowl
# 2600      1032         1  Steak Salad Bowl
# 2624      1042         1  Steak Salad Bowl
# 2740      1088         1  Steak Salad Bowl
# 2804      1114         1  Steak Salad Bowl
# 2957      1176         1  Steak Salad Bowl
# 3098      1235         1  Steak Salad Bowl
# 3120      1244         1  Steak Salad Bowl
# 3350      1343         1  Steak Salad Bowl
# ...

# %%
df[df.item_name=='Steak Burrito'].choice_description.value_counts()
# Out:
# [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice, Cheese, Sour Cream]]                                                        12
# [Roasted Chili Corn Salsa (Medium), [Rice, Fajita Veggies, Cheese, Sour Cream, Lettuce]]                                     6
# [Tomatillo Green Chili Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Lettuce]]                                        6
# [[Roasted Chili Corn Salsa (Medium), Tomatillo-Red Chili Salsa (Hot)], [Black Beans, Rice, Cheese, Sour Cream, Lettuce]]     5
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]                                            5
#                                                                                                                             ..
# [Fresh Tomato Salsa, [Rice, Fajita Vegetables, Black Beans, Sour Cream, Cheese, Lettuce]]                                    1
# ...

# %%
df[df.item_name=='Steak Burrito'].choice_description.nunique()
# Out:
# 251

# %%
df.dropna(inplace=True)

# %%
df[df.choice_description.str.contains('Black Beans')].item_name.value_counts()
# Out:
# Chicken Bowl             386
# Chicken Burrito          282
# Steak Burrito            148
# Steak Bowl               110
# Veggie Bowl               60
# Veggie Burrito            55
# Chicken Salad Bowl        49
# Carnitas Bowl             39
# Barbacoa Bowl             37
# Barbacoa Burrito          30
# Carnitas Burrito          28
# Chicken Soft Tacos        19
# Chicken Crispy Tacos      14
# Veggie Salad Bowl         13
# Steak Salad Bowl          13
# Steak Soft Tacos          10
# Carnitas Soft Tacos        7
# Chicken Salad              7
# Veggie Soft Tacos          6
# Barbacoa Soft Tacos        6
# Veggie Salad               5
# Barbacoa Salad Bowl        4
# Barbacoa Crispy Tacos      3
# Carnitas Crispy Tacos      3
# Carnitas Salad Bowl        3
# Steak Crispy Tacos         2
# Steak Salad                2
# Salad                      2
# Burrito                    1
# Carnitas Salad             1
# Name: item_name, dtype: int64

# %%
df[(df.item_price<10) & (df.item_name=='Chicken Bowl')]
# Out:
#       order_id  quantity     item_name  \
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# 76          34         1  Chicken Bowl
# 78          34         1  Chicken Bowl
# 99          44         1  Chicken Bowl
# ...        ...       ...           ...
# 4583      1823         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# 76    [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...        8.75
# 78    [Fresh Tomato Salsa, [Rice, Black Beans, Chees...        8.75
# 99    [Tomatillo Red Chili Salsa, [Rice, Fajita Vege...        8.75
# ...                                                 ...         ...
# ...

# %%
df[(df.item_price<10) & (df.item_name=='Chicken Bowl')].sort_values(['item_price'])
# Out:
#       order_id  quantity     item_name  \
# 3664      1466         1  Chicken Bowl
# 2918      1160         1  Chicken Bowl
# 3101      1237         1  Chicken Bowl
# 3396      1362         1  Chicken Bowl
# 1645       665         1  Chicken Bowl
# ...        ...       ...           ...
# 1876       759         1  Chicken Bowl
# 1852       751         1  Chicken Bowl
# 1851       750         1  Chicken Bowl
# 1829       740         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 3664  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 2918  [Fresh Tomato (Mild), [Rice, Sour Cream, Cheese]]        8.19
# 3101  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 3396  [Tomatillo-Green Chili Salsa (Medium), [Pinto ...        8.49
# 1645  [[Fresh Tomato Salsa (Mild), Tomatillo-Red Chi...        8.49
# ...                                                 ...         ...
# ...

# %%
import pandas as pd
movies=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/imdb_1000.csv")
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies[(movies.content_rating=='R') & (movies.star_rating>=8)].sort_values(['duration'])
# Out:
#      star_rating                        title content_rating      genre  \
# 283          8.1                Before Sunset              R      Drama
# 306          8.0           This Is Spinal Tap              R     Comedy
# 225          8.1                       3-Iron              R      Crime
# 206          8.1                  Stand by Me              R  Adventure
# 190          8.2                Life of Brian              R     Comedy
# ..           ...                          ...            ...        ...
# 316          8.0                          JFK              R      Drama
# 40           8.5               The Green Mile              R      Crime
# 8            8.9             Schindler's List              R  Biography
# 2            9.1       The Godfather: Part II              R      Crime
# 78           8.4  Once Upon a Time in America              R      Crime
#
#      duration                                        actors_list
# ...

# %%
movies[movies.actors_list.str.contains('Ethan Hawke')]
# Out:
#      star_rating               title content_rating  genre  duration  \
# 226          8.1             Boyhood              R  Drama       165
# 238          8.1      Before Sunrise              R  Drama       105
# 283          8.1       Before Sunset              R  Drama        80
# 342          8.0  Dead Poets Society             PG  Drama       128
# 372          8.0     Before Midnight              R  Drama       109
# 499          7.8             Gattaca          PG-13  Drama       106
# 636          7.7        Training Day              R  Crime       122
# 724          7.6         Lord of War              R  Crime       122
# 939          7.4      Predestination              R  Drama        97
#
#                                            actors_list
# 226  [u'Ellar Coltrane', u'Patricia Arquette', u'Et...
# 238  [u'Ethan Hawke', u'Julie Delpy', u'Andrea Ecke...
# 283  [u'Ethan Hawke', u'Julie Delpy', u'Vernon Dobt...
# 342  [u'Robin Williams', u'Robert Sean Leonard', u'...
# ...

# %%
movies[movies.actors_list.str.contains('Robin Williams')].sort_values(['star_rating','duration'],ascending=(False,True))
# Out:
#      star_rating               title content_rating      genre  duration  \
# 139          8.3   Good Will Hunting              R      Drama       126
# 357          8.0             Aladdin              G  Animation        90
# 342          8.0  Dead Poets Society             PG      Drama       128
# 579          7.8          Awakenings          PG-13  Biography       121
# 808          7.6     The Fisher King              R     Comedy       137
#
#                                            actors_list
# 139  [u'Robin Williams', u'Matt Damon', u'Ben Affle...
# 357  [u'Scott Weinger', u'Robin Williams', u'Linda ...
# 342  [u'Robin Williams', u'Robert Sean Leonard', u'...
# 579  [u'Robert De Niro', u'Robin Williams', u'Julie...
# 808  [u'Jeff Bridges', u'Robin Williams', u'Adam Br...

# %%
import pandas as pd
ufo=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/ufo.csv")
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.dropna(subset=['City','Shape Reported'],how='any').shape
# Out:
# (15576, 5)

# %%
ufo.dropna(subset=['City','Shape Reported'],how='all').shape
# Out:
# (18237, 5)

# %%
ufo['Shape Reported'].isnull().sum()#remove values where columns represent the attributes# isnull
# Out:
# 2644

# %%
import pandas as pd
drinks=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/drinks.csv")
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
drinks.beer_servings.min()
# Out:
# 0

# %%
drinks.beer_servings.max()
# Out:
# 376

# %%
drinks[drinks.continent=='Asia'].describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count      44.000000        44.000000      44.000000
# mean       37.045455        60.840909       9.068182
# std        49.469725        84.362160      21.667034
# min         0.000000         0.000000       0.000000
# 25%         4.250000         1.000000       0.000000
# 50%        17.500000        16.000000       1.000000
# 75%        60.500000        98.000000       8.000000
# max       247.000000       326.000000     123.000000
#
#        total_litres_of_pure_alcohol
# count                     44.000000
# mean                       2.170455
# std                        2.770239
# min                        0.000000
# 25%                        0.100000
# 50%                        1.200000
# 75%                        2.425000
# max                       11.500000

# %%
drinks[drinks.continent=='Asia'].beer_servings.agg(['mean','min','max'])
# Out:
# mean     37.045455
# min       0.000000
# max     247.000000
# Name: beer_servings, dtype: float64

# %%
drinks.groupby('continent').beer_servings.max()
# Out:
# continent
# Africa           376
# Asia             247
# Europe           361
# North America    285
# Oceania          306
# South America    333
# Name: beer_servings, dtype: int64

# %%
drinks.groupby('continent').beer_servings.agg(['mean','max','min'])
# Out:
#                      mean  max  min
# continent
# Africa          61.471698  376    0
# Asia            37.045455  247    0
# Europe         193.777778  361    0
# North America  145.434783  285    1
# Oceania         89.687500  306    0
# South America  175.083333  333   93
