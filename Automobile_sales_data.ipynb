# %% [markdown]
# <a href="https://colab.research.google.com/github/POOJITHA1334/ML/blob/main/Automobile_sales_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/Auto Sales data.csv')
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10168               36      96.66                1  3479.76
# ...           ...              ...        ...              ...      ...
# 2742        10350               20     112.22               15  2244.40
# 2743        10373               29     137.19                1  3978.51
# 2744        10386               43     125.99                4  5417.57
# 2745        10397               34      62.24                1  2116.16
# 2746        10414               47      65.52                9  3079.44
#
#        ORDERDATE  DAYS_SINCE_LASTORDER    STATUS  PRODUCTLINE  MSRP  \
# ...

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2747.000000      2747.000000  2747.000000      2747.000000
# mean   10259.761558        35.103021   101.098952         6.491081
# std       91.877521         9.762135    42.042549         4.230544
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10181.000000        27.000000    68.745000         3.000000
# 50%    10264.000000        35.000000    95.550000         6.000000
# 75%    10334.500000        43.000000   127.100000         9.000000
# max    10425.000000        97.000000   252.870000        18.000000
#
#               SALES  DAYS_SINCE_LASTORDER         MSRP
# count   2747.000000           2747.000000  2747.000000
# mean    3553.047583           1757.085912   100.691664
# std     1838.953901            819.280576    40.114802
# min      482.130000             42.000000    33.000000
# 25%     2204.350000           1077.000000    68.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2747 entries, 0 to 2746
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ORDERNUMBER           2747 non-null   int64
#  1   QUANTITYORDERED       2747 non-null   int64
#  2   PRICEEACH             2747 non-null   float64
#  3   ORDERLINENUMBER       2747 non-null   int64
#  4   SALES                 2747 non-null   float64
#  5   ORDERDATE             2747 non-null   object
#  6   DAYS_SINCE_LASTORDER  2747 non-null   int64
#  7   STATUS                2747 non-null   object
#  8   PRODUCTLINE           2747 non-null   object
#  9   MSRP                  2747 non-null   int64
#  10  PRODUCTCODE           2747 non-null   object
#  11  CUSTOMERNAME          2747 non-null   object
#  12  PHONE                 2747 non-null   object
#  13  ADDRESSLINE1          2747 non-null   object
#  14  CITY                  2747 non-null   object
# ...

# %%
df.tail()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2742        10350               20     112.22               15  2244.40
# 2743        10373               29     137.19                1  3978.51
# 2744        10386               43     125.99                4  5417.57
# 2745        10397               34      62.24                1  2116.16
# 2746        10414               47      65.52                9  3079.44
#
#        ORDERDATE  DAYS_SINCE_LASTORDER    STATUS PRODUCTLINE  MSRP  \
# 2742  02/12/2019                  2924   Shipped       Ships    54
# 2743  31/01/2020                  2865   Shipped       Ships    54
# 2744  01/03/2020                  2836  Resolved       Ships    54
# 2745  28/03/2020                  2810   Shipped       Ships    54
# 2746  06/05/2020                  2772   On Hold       Ships    54
#
#      PRODUCTCODE             CUSTOMERNAME           PHONE  \
# 2742    S72_3212    Euro Shopping Channel  (91) 555 94 44
# ...

# %%
df.isnull()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  SALES  \
# 0           False            False      False            False  False
# 1           False            False      False            False  False
# 2           False            False      False            False  False
# 3           False            False      False            False  False
# 4           False            False      False            False  False
# ...           ...              ...        ...              ...    ...
# 2742        False            False      False            False  False
# 2743        False            False      False            False  False
# 2744        False            False      False            False  False
# 2745        False            False      False            False  False
# 2746        False            False      False            False  False
#
#       ORDERDATE  DAYS_SINCE_LASTORDER  STATUS  PRODUCTLINE   MSRP  \
# ...

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER             0
# QUANTITYORDERED         0
# PRICEEACH               0
# ORDERLINENUMBER         0
# SALES                   0
# ORDERDATE               0
# DAYS_SINCE_LASTORDER    0
# STATUS                  0
# PRODUCTLINE             0
# MSRP                    0
# PRODUCTCODE             0
# CUSTOMERNAME            0
# PHONE                   0
# ADDRESSLINE1            0
# CITY                    0
# POSTALCODE              0
# COUNTRY                 0
# CONTACTLASTNAME         0
# CONTACTFIRSTNAME        0
# DEALSIZE                0
# dtype: int64

# %%
df.columns.tolist()
# Out:
# ['ORDERNUMBER',
#  'QUANTITYORDERED',
#  'PRICEEACH',
#  'ORDERLINENUMBER',
#  'SALES',
#  'ORDERDATE',
#  'DAYS_SINCE_LASTORDER',
#  'STATUS',
#  'PRODUCTLINE',
#  'MSRP',
#  'PRODUCTCODE',
#  'CUSTOMERNAME',
#  'PHONE',
#  'ADDRESSLINE1',
#  'CITY',
#  'POSTALCODE',
#  'COUNTRY',
#  'CONTACTLASTNAME',
#  'CONTACTFIRSTNAME',
#  'DEALSIZE']

# %%
df_auto = df[df.SALES < 3500]
df_auto
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 4           10168               36      96.66                1  3479.76
# 5           10180               29      86.13                9  2497.77
# 9           10237               23     101.44                7  2333.12
# ...           ...              ...        ...              ...      ...
# 2739        10315               40      55.69                5  2227.60
# 2740        10327               37      86.74                4  3209.38
# 2742        10350               20     112.22               15  2244.40
# 2745        10397               34      62.24                1  2116.16
# 2746        10414               47      65.52                9  3079.44
#
#        ORDERDATE  DAYS_SINCE_LASTORDER    STATUS  PRODUCTLINE  MSRP  \
# ...

# %%
df_auto.COUNTRY.value_counts()
# Out:
# USA            527
# Spain          198
# France         180
# Australia      108
# UK              84
# Italy           73
# Finland         52
# Canada          47
# Norway          46
# Singapore       44
# Denmark         39
# Germany         35
# Sweden          31
# Austria         29
# Japan           29
# Belgium         21
# Philippines     15
# Switzerland     13
# Ireland          8
# Name: COUNTRY, dtype: int64

# %%
c=df[df.CITY=='Madrid']
c
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 23          10417               66     113.88                2   7516.08
# 26          10126               38     192.87               11   7329.06
# 49          10424               50     240.02                6  12001.00
# 73          10417               45     130.83                5   5887.35
# 97          10417               56     164.61                4   9218.16
# ...           ...              ...        ...              ...       ...
# 2717        10386               50      87.15               16   4357.50
# 2725        10153               50      60.06                4   3003.00
# 2727        10177               40      50.23                6   2009.20
# 2742        10350               20     112.22               15   2244.40
# 2744        10386               43     125.99                4   5417.57
#
#        ORDERDATE  DAYS_SINCE_LASTORDER      STATUS   PRODUCTLINE  MSRP  \
# ...

# %%
d=c[c.QUANTITYORDERED<50]
d
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 26          10126               38     192.87               11  7329.06
# 73          10417               45     130.83                5  5887.35
# 117         10350               26      75.47                5  1962.22
# 125         10126               22     152.17                4  3347.74
# 157         10203               20     196.52                8  3930.40
# ...           ...              ...        ...              ...      ...
# 2691        10386               44      86.40               15  3801.60
# 2706        10262               21      57.11               12  1199.31
# 2727        10177               40      50.23                6  2009.20
# 2742        10350               20     112.22               15  2244.40
# 2744        10386               43     125.99                4  5417.57
#
#        ORDERDATE  DAYS_SINCE_LASTORDER     STATUS   PRODUCTLINE  MSRP  \
# ...

# %%
d.dtypes
# Out:
# ORDERNUMBER               int64
# QUANTITYORDERED           int64
# PRICEEACH               float64
# ORDERLINENUMBER           int64
# SALES                   float64
# ORDERDATE                object
# DAYS_SINCE_LASTORDER      int64
# STATUS                   object
# PRODUCTLINE              object
# MSRP                      int64
# PRODUCTCODE              object
# CUSTOMERNAME             object
# PHONE                    object
# ADDRESSLINE1             object
# CITY                     object
# POSTALCODE               object
# COUNTRY                  object
# CONTACTLASTNAME          object
# CONTACTFIRSTNAME         object
# DEALSIZE                 object
# dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df['SALES'].hist()
# Out:
# <Axes: >

# %%
plt.bar(df["QUANTITYORDERED"],df["SALES"])
plt.xlabel("SALES")
plt.ylabel('QUANTITY')
plt.title("AUTOMOBILE SALES")
plt.show()

# %%
Q1=df['SALES'].quantile(0.25)
Q3=df['SALES'].quantile(0.75)
IQR = Q3-Q1
lower=Q1-1.5*IQR
upper=Q3+1.5*IQR
upper_arrays=np.where(df['SALES']>=upper)[0]
lower_arrays=np.where(df['SALES']<=lower)[0]
Q1
# Out:
# 2204.35

# %%
import seaborn as sns
df.corr()
sns.heatmap(df.corr())
# Out:
# <ipython-input-33-30a6d455a720>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
# <ipython-input-33-30a6d455a720>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
auto=df['SALES']
auto
# Out:
# 0       2871.00
# 1       2765.90
# 2       3884.34
# 3       3746.70
# 4       3479.76
#          ...
# 2742    2244.40
# 2743    3978.51
# 2744    5417.57
# 2745    2116.16
# 2746    3079.44
# Name: SALES, Length: 2747, dtype: float64

# %%
auto.max()
# Out:
# 14082.8

# %%
sns.boxplot(auto)
# Out:
# <Axes: >

# %%
auto_bar = pd.DataFrame(np.random.randint(low=2, high=100, size=(10,2)),columns=['QUANTITYORDERED', 'SALES'])
auto_bar
# Out:
#    QUANTITYORDERED  SALES
# 0               99     64
# 1               63     68
# 2               67     90
# 3               68     55
# 4               59     36
# 5               41     90
# 6               98     90
# 7               85     29
# 8               37     65
# 9               47     22

# %%
auto_bar.plot.bar()
# Out:
# <Axes: >

# %%
auto_bar = pd.DataFrame(np.random.randint(low=2, high=100, size=(10,2)),columns=['SALES', 'MSRP'])
auto_bar
# Out:
#    SALES  MSRP
# 0     22    34
# 1     91    68
# 2     57    74
# 3     84    30
# 4     17    85
# 5     38    82
# 6     70    46
# 7     19    60
# 8     78    56
# 9     74    24

# %%
auto_bar.plot.bar()
# Out:
# <Axes: >

# %%
labels = 'SALES', 'MSRP', 'QUANTITYORDERED'
sections = [56, 66, 24]
colors = ['b', 'r', 'g']
plt.pie(sections, labels=labels, colors=colors, autopct='%.2f%%', explode = (0, 0.1, 0))
# Out:
# ([<matplotlib.patches.Wedge at 0x7acd63e50ca0>,
# ...
#  [Text(0.39346807193873345, 1.0272209481726977, 'SALES'),
#   Text(-0.9265879053108963, -0.7625187563146009, 'MSRP'),
#   Text(0.9565483303711487, -0.543153101495488, 'QUANTITYORDERED')],
#  [Text(0.21461894833021822, 0.560302335366926, '38.36%'),
#   Text(-0.5405096114313561, -0.4448026078501838, '45.21%'),
#   Text(0.5217536347478993, -0.29626532808844797, '16.44%')])

# %%
df.COUNTRY.nunique()
# Out:
# 19

# %%
a=df.head(10)
a
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10168               36      96.66                1  3479.76
# 5        10180               29      86.13                9  2497.77
# 6        10188               48     114.84                1  5512.32
# 7        10211               41     114.84               14  4708.44
# 8        10223               37     107.18                1  3965.66
# 9        10237               23     101.44                7  2333.12
#
#     ORDERDATE  DAYS_SINCE_LASTORDER   STATUS  PRODUCTLINE  MSRP PRODUCTCODE  \
# 0  24/02/2018                   828  Shipped  Motorcycles    95    S10_1678
# ...

# %%
x=a.iloc[:,6].values
x
# Out:
# array([828, 757, 703, 649, 586, 573, 567, 510, 475, 432])

# %%
x=x.reshape(-1, 1)
x
# Out:
# array([[828],
#        [757],
#        [703],
#        [649],
#        [586],
#        [573],
#        [567],
#        [510],
#        [475],
#        [432]])

# %%
y=a.iloc[:,3].values
y
# Out:
# array([ 2,  5,  2,  6,  1,  9,  1, 14,  1,  7])

# %%
from sklearn.linear_model import LinearRegression
harmness=LinearRegression()
harmness.fit(x,y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y,color='red')
plt.plot(x,harmness.predict(x),color='blue')
plt.title('auuto data')
plt.xlabel('quantity')
plt.ylabel('sales')
plt.show()

# %%
plt.subplots(figsize=(12,6))
sns.heatmap(df.corr(),annot=True,cmap='Blues',)
# Out:
# <ipython-input-54-77b6117d440d>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap='Blues',)
# <Axes: >

# %%
from sklearn.preprocessing import PolynomialFeatures
auto=PolynomialFeatures(degree=2,include_bias=False)

# %%
auto_index=auto.fit_transform(x)
auto_index.shape
# Out:
# (10, 2)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(auto_index,y,test_size=0.3,random_state=101)

# %%
y=df['SALES']
y
# Out:
# 0       2871.00
# 1       2765.90
# 2       3884.34
# 3       3746.70
# 4       3479.76
#          ...
# 2742    2244.40
# 2743    3978.51
# 2744    5417.57
# 2745    2116.16
# 2746    3079.44
# Name: SALES, Length: 2747, dtype: float64

# %%
b=LinearRegression()

# %%
b.fit(x_train,y_train)
# Out:
# LinearRegression()
